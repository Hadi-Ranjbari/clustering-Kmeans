# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('diabetes.csv')
df
# Out:
#         id   chol  stab.glu   hdl  ratio      glyhb    location  age  gender  \
# 0     1000  203.0        82  56.0    3.6   4.310000  Buckingham   46  female
# 1     1001  165.0        97  24.0    6.9   4.440000  Buckingham   29  female
# 2     1002  228.0        92  37.0    6.2   4.640000  Buckingham   58  female
# 3     1003   78.0        93  12.0    6.5   4.630000  Buckingham   67    male
# 4     1005  249.0        90  28.0    8.9   7.720000  Buckingham   64    male
# ..     ...    ...       ...   ...    ...        ...         ...  ...     ...
# 398  41506  296.0       369  46.0    6.4  16.110001      Louisa   53    male
# 399  41507  284.0        89  54.0    5.3   4.390000      Louisa   51  female
# 400  41510  194.0       269  38.0    5.1  13.630000      Louisa   29  female
# 401  41752  199.0        76  52.0    3.8   4.490000      Louisa   41  female
# 402  41756  159.0        88  79.0    2.0        NaN      Louisa   68  female
#
# ...

# %%
df.describe()
# Out:
#                  id        chol    stab.glu         hdl       ratio  \
# count    403.000000  402.000000  403.000000  402.000000  402.000000
# mean   15978.310174  207.845771  106.672457   50.445274    4.521642
# std    11881.122124   44.445557   53.076655   17.262626    1.727886
# min     1000.000000   78.000000   48.000000   12.000000    1.500000
# 25%     4792.500000  179.000000   81.000000   38.000000    3.200000
# 50%    15766.000000  204.000000   89.000000   46.000000    4.200000
# 75%    20336.000000  230.000000  106.000000   59.000000    5.400000
# max    41756.000000  443.000000  385.000000  120.000000   19.299999
#
#             glyhb         age      height      weight       bp.1s       bp.1d  \
# count  390.000000  403.000000  398.000000  402.000000  398.000000  398.000000
# mean     5.589769   46.851117   66.020101  177.592040  136.904523   83.321608
# std      2.242595   16.312333    3.918515   40.340666   22.741033   13.589227
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403 entries, 0 to 402
# Data columns (total 19 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        403 non-null    int64
#  1   chol      402 non-null    float64
#  2   stab.glu  403 non-null    int64
#  3   hdl       402 non-null    float64
#  4   ratio     402 non-null    float64
#  5   glyhb     390 non-null    float64
#  6   location  403 non-null    object
#  7   age       403 non-null    int64
#  8   gender    403 non-null    object
#  9   height    398 non-null    float64
#  10  weight    402 non-null    float64
#  11  frame     391 non-null    object
#  12  bp.1s     398 non-null    float64
#  13  bp.1d     398 non-null    float64
#  14  bp.2s     141 non-null    float64
#  15  bp.2d     141 non-null    float64
#  16  waist     401 non-null    float64
#  17  hip       401 non-null    float64
#  18  time.ppn  400 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# id            0
# chol          1
# stab.glu      0
# hdl           1
# ratio         1
# glyhb        13
# location      0
# age           0
# gender        0
# height        5
# weight        1
# frame        12
# bp.1s         5
# bp.1d         5
# bp.2s       262
# bp.2d       262
# waist         2
# hip           2
# time.ppn      3
# dtype: int64

# %%
df = df.drop(['bp.2s', 'bp.2d','id'], axis=1)

# %%
df.isnull().sum()
# Out:
# chol         1
# stab.glu     0
# hdl          1
# ratio        1
# glyhb       13
# location     0
# age          0
# gender       0
# height       5
# weight       1
# frame       12
# bp.1s        5
# bp.1d        5
# waist        2
# hip          2
# time.ppn     3
# dtype: int64

# %%
sns.distplot(df['glyhb'])
# Out:
# /tmp/ipykernel_7144/2711512756.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['glyhb'])
# <Axes: xlabel='glyhb', ylabel='Density'>

# %%
df['glyhb'].fillna(df['glyhb'].median(), inplace=True)
df.isnull().sum()
# Out:
# chol         1
# stab.glu     0
# hdl          1
# ratio        1
# glyhb        0
# location     0
# age          0
# gender       0
# height       5
# weight       1
# frame       12
# bp.1s        5
# bp.1d        5
# waist        2
# hip          2
# time.ppn     3
# dtype: int64

# %%
sns.distplot(df['glyhb'])
# Out:
# /tmp/ipykernel_7144/2711512756.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['glyhb'])
# <Axes: xlabel='glyhb', ylabel='Density'>

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# /tmp/ipykernel_7144/1515604522.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %%
df
# Out:
#       chol  stab.glu   hdl  ratio      glyhb    location  age  gender  height  \
# 0    203.0        82  56.0    3.6   4.310000  Buckingham   46  female    62.0
# 1    165.0        97  24.0    6.9   4.440000  Buckingham   29  female    64.0
# 2    228.0        92  37.0    6.2   4.640000  Buckingham   58  female    61.0
# 3     78.0        93  12.0    6.5   4.630000  Buckingham   67    male    67.0
# 4    249.0        90  28.0    8.9   7.720000  Buckingham   64    male    68.0
# ..     ...       ...   ...    ...        ...         ...  ...     ...     ...
# 398  296.0       369  46.0    6.4  16.110001      Louisa   53    male    69.0
# 399  284.0        89  54.0    5.3   4.390000      Louisa   51  female    63.0
# 400  194.0       269  38.0    5.1  13.630000      Louisa   29  female    69.0
# 401  199.0        76  52.0    3.8   4.490000      Louisa   41  female    63.0
# 402  159.0        88  79.0    2.0   4.840000      Louisa   68  female    64.0
#
# ...

# %%
glyhb_med = np.median(df['glyhb'])
df['glyhb'].fillna(value=glyhb_med)
df['glyhb'].isnull().sum()
# Out:
# 0

# %%
df
# Out:
#       chol  stab.glu   hdl  ratio      glyhb    location  age  gender  height  \
# 0    203.0        82  56.0    3.6   4.310000  Buckingham   46  female    62.0
# 1    165.0        97  24.0    6.9   4.440000  Buckingham   29  female    64.0
# 2    228.0        92  37.0    6.2   4.640000  Buckingham   58  female    61.0
# 3     78.0        93  12.0    6.5   4.630000  Buckingham   67    male    67.0
# 4    249.0        90  28.0    8.9   7.720000  Buckingham   64    male    68.0
# ..     ...       ...   ...    ...        ...         ...  ...     ...     ...
# 398  296.0       369  46.0    6.4  16.110001      Louisa   53    male    69.0
# 399  284.0        89  54.0    5.3   4.390000      Louisa   51  female    63.0
# 400  194.0       269  38.0    5.1  13.630000      Louisa   29  female    69.0
# 401  199.0        76  52.0    3.8   4.490000      Louisa   41  female    63.0
# 402  159.0        88  79.0    2.0   4.840000      Louisa   68  female    64.0
#
# ...

# %%
df.isnull().sum()
# Out:
# chol         1
# stab.glu     0
# hdl          1
# ratio        1
# glyhb        0
# location     0
# age          0
# gender       0
# height       5
# weight       1
# frame       12
# bp.1s        5
# bp.1d        5
# waist        2
# hip          2
# time.ppn     3
# dtype: int64

# %%
df['frame'].unique()
# Out:
# array(['medium', 'large', 'small', nan], dtype=object)

# %%
new_df = pd.get_dummies(df,drop_first=True)
new_df = new_df.dropna()

# %%
new_df
# Out:
#       chol  stab.glu   hdl  ratio      glyhb  age  height  weight  bp.1s  \
# 0    203.0        82  56.0    3.6   4.310000   46    62.0   121.0  118.0
# 1    165.0        97  24.0    6.9   4.440000   29    64.0   218.0  112.0
# 2    228.0        92  37.0    6.2   4.640000   58    61.0   256.0  190.0
# 3     78.0        93  12.0    6.5   4.630000   67    67.0   119.0  110.0
# 4    249.0        90  28.0    8.9   7.720000   64    68.0   183.0  138.0
# ..     ...       ...   ...    ...        ...  ...     ...     ...    ...
# 398  296.0       369  46.0    6.4  16.110001   53    69.0   173.0  138.0
# 399  284.0        89  54.0    5.3   4.390000   51    63.0   154.0  140.0
# 400  194.0       269  38.0    5.1  13.630000   29    69.0   167.0  120.0
# 401  199.0        76  52.0    3.8   4.490000   41    63.0   197.0  120.0
# 402  159.0        88  79.0    2.0   4.840000   68    64.0   220.0  100.0
#
#      bp.1d  waist   hip  time.ppn  location_Louisa  gender_male  frame_medium  \
# ...

# %%
plt.figure(figsize = (14,9))
sns.heatmap(new_df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Feature selection

# %%
y = new_df[['time.ppn']]
X = new_df.drop('time.ppn', axis=1)
print(X.columns[12] , X.columns[0])
print(X.shape, y.shape)
# Out:
# location_Louisa chol
# (388, 16) (388, 1)

# %%
print(X.isnull().sum())
print(y.isnull().sum())
# Out:
# chol               0
# stab.glu           0
# hdl                0
# ratio              0
# glyhb              0
# age                0
# height             0
# weight             0
# bp.1s              0
# bp.1d              0
# waist              0
# hip                0
# location_Louisa    0
# gender_male        0
# frame_medium       0
# frame_small        0
# dtype: int64
# time.ppn    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest, f_classif
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=101, test_size=0.2)

# %%
# we can use f score ANOVA to feature selection
fs = SelectKBest(k='all', score_func=f_classif)
fs.fit(X_train, y_train)
fs_X_train = fs.transform(X_train)
fs_X_test = fs.transform(X_test)
# Out:
# /usr/lib/python3.11/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# we can plot the each variable and the biiger is better
for i in range(len(fs.scores_)):
    plt.bar([i for i in range(len(fs.scores_))], fs.scores_)
    plt.show()
    break
    
# location lusia & chol & ratio & hdl & glyhb
print(sorted(fs.scores_))
# Out:
# [0.495257464613069, 0.8149572481060086, 0.8970613696541759, 0.8994034805518561, 0.9535608454111338, 0.9786475122859918, 0.9802426690174345, 1.0026313358305297, 1.0499351943781807, 1.066105274175536, 1.0826967039968232, 1.0864644758600146, 1.1355698922947821, 1.166290602082842, 1.3309170694207555, 1.6547473037577078]

# %%
X.columns[12]
# Out:
# 'location_Louisa'

# %%
new_X = X[['ratio', 'glyhb', 'hdl','chol', 'location_Louisa']]
final_df = pd.concat([new_X, y], axis = 1)
final_df
# Out:
#      ratio      glyhb   hdl   chol  location_Louisa  time.ppn
# 0      3.6   4.310000  56.0  203.0                0     720.0
# 1      6.9   4.440000  24.0  165.0                0     360.0
# 2      6.2   4.640000  37.0  228.0                0     180.0
# 3      6.5   4.630000  12.0   78.0                0     480.0
# 4      8.9   7.720000  28.0  249.0                0     300.0
# ..     ...        ...   ...    ...              ...       ...
# 398    6.4  16.110001  46.0  296.0                1     210.0
# 399    5.3   4.390000  54.0  284.0                1     180.0
# 400    5.1  13.630000  38.0  194.0                1      20.0
# 401    3.8   4.490000  52.0  199.0                1     255.0
# 402    2.0   4.840000  79.0  159.0                1     900.0
#
# [388 rows x 6 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(final_df)
X = pd.DataFrame(X , columns=['ratio', 'glyhb','hdl', 'chol', 'location_Lousia', 'time.ppn'])
X
# Out:
#         ratio     glyhb       hdl      chol  location_Lousia  time.ppn
# 0   -0.528248 -0.581079  0.310009 -0.116198        -1.015585  1.227396
# 1    1.366342 -0.521466 -1.531651 -0.972811        -1.015585  0.063574
# 2    0.964459 -0.429755 -0.783477  0.447363        -1.015585 -0.518338
# 3    1.136695 -0.434341 -2.222274 -2.934003        -1.015585  0.451515
# 4    2.514578  0.982600 -1.301444  0.920754        -1.015585 -0.130397
# ..        ...       ...       ...       ...              ...       ...
# 383  1.079283  4.829891 -0.265510  1.980249         0.984654 -0.421353
# 384  0.447753 -0.544394  0.194905  1.709739         0.984654 -0.518338
# 385  0.332929  3.692670 -0.725925 -0.319080         0.984654 -1.035592
# 386 -0.413424 -0.498539  0.079801 -0.206368         0.984654 -0.275875
# 387 -1.446837 -0.338044  1.633702 -1.108065         0.984654  1.809308
#
# [388 rows x 6 columns]

# %%
# now we want to use PCA to find the best features
from sklearn.decomposition import PCA
pca = PCA(n_components=6)
p_components = pca.fit_transform(X)

# %%
# Plot the explained variances
features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_ratio_, color='black')
plt.xlabel('PCA features')
plt.ylabel('variance %')
plt.xticks(features)
# Out:
# ([<matplotlib.axis.XTick at 0x7f34602f37d0>,
# ...
#  [Text(0, 0, '0'),
#   Text(1, 0, '1'),
#   Text(2, 0, '2'),
#   Text(3, 0, '3'),
#   Text(4, 0, '4'),
#   Text(5, 0, '5')])

# %%
PCA_components = pd.DataFrame(p_components)
PCA_components
# Out:
#             0         1         2         3         4         5
# 0   -0.891811  0.412539 -1.371258  0.249184 -0.579982 -0.141019
# 1    1.091501 -1.734894 -1.230067 -0.118830 -0.731737  0.450260
# 2    1.043290 -0.473009 -0.396227 -0.793487 -1.062650 -0.029912
# 3    0.579920 -3.282751 -2.093375  0.364874  0.155726  0.781355
# 4    3.070895 -0.021792 -0.795988 -0.546099 -0.550000  0.461925
# ..        ...       ...       ...       ...       ...       ...
# 383  3.612443  2.363053  0.790444 -0.375994  3.172216 -0.410814
# 384  0.640288  0.825956  1.565281  0.229727 -0.999632 -0.319291
# 385  2.084220  0.077756  0.647101 -0.501609  3.374205 -0.108614
# 386 -0.569015 -0.360476  0.910207  0.470035  0.039962 -0.096641
# 387 -2.433747  0.752457 -0.323961  1.692761  0.788964  0.515138
#
# [388 rows x 6 columns]

# %%
plt.scatter(PCA_components[0], PCA_components[1], alpha=.3, color='black')
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
# Out:
# Text(0, 0.5, 'PCA 2')

# %%
ks = range(1, 10)
inertias = []
for k in ks:
    # Create a KMeans instance with k clusters: model
    model = KMeans(n_clusters=k)
    
    # Fit model to samples
    model.fit(PCA_components.iloc[:,:3])
    
    # Append the inertia to the list of inertias
    inertias.append(model.inertia_)
    
plt.plot(ks, inertias, '-o', color='black')
plt.xlabel('number of clusters, k')
plt.ylabel('inertia')
plt.xticks(ks)
plt.show()
# elbow point , k = 4
# Out:
# /usr/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...
